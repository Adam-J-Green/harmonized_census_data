# %%
import pandas as pd
data = pd.read_csv('test.csv', encoding='latin1')
data.info()
data.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16435857 entries, 0 to 16435856
# Data columns (total 22 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   DATAFLOW           object
#  1   FREQ               object
#  2   TIME_PERIOD        int64
#  3   REF_AREA           object
#  4   GENDER             int64
#  5   CHARACTERISTIC     int64
#  6   STATISTIC          int64
#  7   OBS_VALUE          float64
#  8   DECIMALS           float64
#  9   FLAG               float64
#  10  TOPIC              float64
#  11  NOTE               float64
#  12  RELEASE_DATE       float64
#  13  GEO_LEVEL          float64
#  14  ALT_GEO_CODE       float64
#  15  GEO_DESC           float64
#  16  PROV_TERR          float64
#  17  DATA_QUALITY_FLAG  float64
#  18  TNR_LF             float64
#  19  TNR_SF             float64
#  20  CI_LOW             float64
#  21  CI_HIGH            float64
# dtypes: float64(15), int64(4), object(3)
# memory usage: 2.7+ GB
# ...

# %%
data['GEO_LEVEL'].value_counts()
# Out:
# GEO_LEVEL
# Census tract                16435857
# Census metropolitan area      107871
# Census agglomeration           23679
# Name: count, dtype: int64

# %%
print(data['CHARACTERISTIC_NAME'].value_counts())
# Out:
# CHARACTERISTIC_NAME
#   English                                                                                                                                                     37482
#   English and French                                                                                                                                          37482
#   65 years and over                                                                                                                                           37482
#   French                                                                                                                                                      31235
#   Multiple non-official languages                                                                                                                             24988
# ...

# %%
import pandas as pd
#data = pd.read_csv('98-401-X2021007_English_CSV_data.csv', encoding = 'latin1')
#data = data[data['GEO_LEVEL'] == 'Census tract']
data.iloc[60:100,:15]
# Out:
#       CENSUS_YEAR                DGUID  ALT_GEO_CODE     GEO_LEVEL  \
# 2691         2021  2021S05079320001.00     9320001.0  Census tract
# 2692         2021  2021S05079320001.00     9320001.0  Census tract
# 2693         2021  2021S05079320001.00     9320001.0  Census tract
# 2694         2021  2021S05079320001.00     9320001.0  Census tract
# 2695         2021  2021S05079320001.00     9320001.0  Census tract
# 2696         2021  2021S05079320001.00     9320001.0  Census tract
# 2697         2021  2021S05079320001.00     9320001.0  Census tract
# 2698         2021  2021S05079320001.00     9320001.0  Census tract
# 2699         2021  2021S05079320001.00     9320001.0  Census tract
# 2700         2021  2021S05079320001.00     9320001.0  Census tract
# 2701         2021  2021S05079320001.00     9320001.0  Census tract
# 2702         2021  2021S05079320001.00     9320001.0  Census tract
# 2703         2021  2021S05079320001.00     9320001.0  Census tract
# ...

# %%
geos = list(data['ALT_GEO_CODE'].unique())

# %%
print(len(geos))
print(len(others))
# Out:
# 6338
# 5770

# %%
print(data2['ALT_GEO_CODE'].value_counts())
data['ALT_GEO_CODE'].value_counts()
# Out:
# ALT_GEO_CODE
# 1            2247
# 1000100      2247
# 1000200      2247
# 1000301      2247
# 1000302      2247
#              ...
# 970010000    2247
# 970010100    2247
# 970010200    2247
# 970010301    2247
# 970010302    2247
# Name: count, Length: 5770, dtype: int64
# ALT_GEO_CODE
# 9320001.00    2631
# 9320002.00    2631
# 9320003.00    2631
# 9320004.00    2631
# 9320005.01    2631
#               ...
# 8600150.00    2631
# 8600160.00    2631
# 8600170.00    2631
# 8600180.00    2631
# 8600190.00    2631
# Name: count, Length: 6247, dtype: int64

# %%
data2[data2['GEO_CODE (POR)'] == 9320005.01].iloc[:, :15]
# Out:
#           CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL GEO_NAME  GNR  GNR_LF  \
# 11511381         2016      9320005.01          2  0005.01  4.4     7.0
# 11511382         2016      9320005.01          2  0005.01  4.4     7.0
# 11511383         2016      9320005.01          2  0005.01  4.4     7.0
# 11511384         2016      9320005.01          2  0005.01  4.4     7.0
# 11511385         2016      9320005.01          2  0005.01  4.4     7.0
# ...               ...             ...        ...      ...  ...     ...
# 11513623         2016      9320005.01          2  0005.01  4.4     7.0
# 11513624         2016      9320005.01          2  0005.01  4.4     7.0
# 11513625         2016      9320005.01          2  0005.01  4.4     7.0
# 11513626         2016      9320005.01          2  0005.01  4.4     7.0
# 11513627         2016      9320005.01          2  0005.01  4.4     7.0
#
#           DATA_QUALITY_FLAG  ALT_GEO_CODE  \
# 11511381                  1     932000501
# ...

# %%
#data2 = pd.read_csv('98-401-X2016043_English_CSV_data.csv')
#print(data2[data2['GEO_CODE (POR)']== '9320001.00'
others = data2['GEO_CODE (POR)'].unique()
matches = []
counter = 0
for item in geos:

    if item in others:
        matches.append(item)
        if counter<5:
            print(item)
    counter+=1
print(len(matches))
# Out:
# 9320001.0
# 9320002.0
# 9320003.0
# 9320004.0
# 9320005.01
# 5365

# %%
import pandas as pd
data = pd.read_csv('98-401-X2016043_English_CSV_data.csv')
data.head()
# Out:
# C:\Users\adam1\AppData\Local\Temp\ipykernel_62044\249115896.py:2: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('98-401-X2016043_English_CSV_data.csv')
#    CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL    GEO_NAME  GNR  GNR_LF  \
# 0         2016             1.0          1  St. John's  3.5     5.3
# 1         2016             1.0          1  St. John's  3.5     5.3
# 2         2016             1.0          1  St. John's  3.5     5.3
# 3         2016             1.0          1  St. John's  3.5     5.3
# 4         2016             1.0          1  St. John's  3.5     5.3
#
#    DATA_QUALITY_FLAG  ALT_GEO_CODE  \
# 0                  0             1
# 1                  0             1
# 2                  0             1
# 3                  0             1
# 4                  0             1
#
#             DIM: Profile of Census Tracts (2247)  \
# 0                               Population, 2016
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12965190 entries, 0 to 12965189
# Data columns (total 14 columns):
#  #   Column                                      Dtype
# ---  ------                                      -----
#  0   CENSUS_YEAR                                 int64
#  1   GEO_CODE (POR)                              float64
#  2   GEO_LEVEL                                   int64
#  3   GEO_NAME                                    object
#  4   GNR                                         float64
#  5   GNR_LF                                      float64
#  6   DATA_QUALITY_FLAG                           int64
#  7   ALT_GEO_CODE                                int64
#  8   DIM: Profile of Census Tracts (2247)        object
#  9   Member ID: Profile of Census Tracts (2247)  int64
#  10  Notes: Profile of Census Tracts (2247)      float64
#  11  Dim: Sex (3): Member ID: [1]: Total - Sex   object
#  12  Dim: Sex (3): Member ID: [2]: Male          object
# ...

# %%
import pandas as pd
data = pd.read_csv("98-401-X2021007_English_CSV_data.csv", encoding = 'latin1')
data.head()
# Out:
# C:\Users\adam1\AppData\Local\Temp\ipykernel_47076\3203426935.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("98-401-X2021007_English_CSV_data.csv", encoding = 'latin1')
#    CENSUS_YEAR         DGUID  ALT_GEO_CODE                 GEO_LEVEL  \
# 0         2021  2021S0503932         932.0  Census metropolitan area
# 1         2021  2021S0503932         932.0  Census metropolitan area
# 2         2021  2021S0503932         932.0  Census metropolitan area
# 3         2021  2021S0503932         932.0  Census metropolitan area
# 4         2021  2021S0503932         932.0  Census metropolitan area
#
#                GEO_NAME  TNR_SF  TNR_LF  DATA_QUALITY_FLAG  CHARACTERISTIC_ID  \
# 0  Abbotsford - Mission     2.7     3.7                  0                  1
# 1  Abbotsford - Mission     2.7     3.7                  0                  2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16567407 entries, 0 to 16567406
# Data columns (total 23 columns):
#  #   Column               Dtype
# ---  ------               -----
#  0   CENSUS_YEAR          int64
#  1   DGUID                object
#  2   ALT_GEO_CODE         float64
#  3   GEO_LEVEL            object
#  4   GEO_NAME             object
#  5   TNR_SF               float64
#  6   TNR_LF               float64
#  7   DATA_QUALITY_FLAG    int64
#  8   CHARACTERISTIC_ID    int64
#  9   CHARACTERISTIC_NAME  object
#  10  CHARACTERISTIC_NOTE  float64
#  11  C1_COUNT_TOTAL       float64
#  12  SYMBOL               object
#  13  C2_COUNT_MEN+        float64
#  14  SYMBOL.1             object
#  15  C3_COUNT_WOMEN+      float64
#  16  SYMBOL.2             object
#  17  C10_RATE_TOTAL       float64
#  18  SYMBOL.3             object
#  19  C11_RATE_MEN+        float64
#  20  SYMBOL.4             object
#  21  C12_RATE_WOMEN+      float64
# ...

# %%
data['GEO_NAME'].value_counts()
# Out:
# GEO_NAME
# 8600190.0               2631
# Abbotsford - Mission    2631
# 9320001.00              2631
# 9320002.00              2631
# 8600006.02              2631
#                         ...
# 5750110.0                 21
# 5410001.03                11
# 5370224.04                10
# 4470008.00                 4
# 5430005.00                 1
# Name: count, Length: 6388, dtype: int64

# %%
import data_processing as dp

proc = dp.DataBuilder()
proc.get_dataset_2016()
proc.get_dataset_2021()
data1, data2 = proc.combine_data()
# Out:
# downloading 2016 census data
# File '2016_cts.zip' downloaded successfully.
# downloading 2021 census data
# File '2021_cts.zip' downloaded successfully.
# c:\Users\adam1\harmonized_census_data\data_processing.py:110: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2016_raw = pd.read_csv(output_file)
# c:\Users\adam1\harmonized_census_data\data_processing.py:97: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_2021_raw = pd.read_csv(output_file, encoding = 'latin1')

# %%
data1.info()
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11454 entries, 0 to 11599
# Data columns (total 8 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   ALT_GEO_CODE                             11454 non-null  float64
#  1   CENSUS_YEAR                              11454 non-null  int64
#  2   AGGREGATE_CT                             11454 non-null  int64
#  3   Average age of the population            11454 non-null  float64
#  4   Average size of census families          11454 non-null  float64
#  5   Population                               11454 non-null  float64
#  6   Population density per square kilometre  11454 non-null  float64
#  7   Total private dwellings                  11454 non-null  float64
# dtypes: float64(6), int64(2)
# memory usage: 805.4 KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 6431 entries, 0 to 6506
# Data columns (total 7 columns):
# ...

# %%
import pandas as pd
t = pd.read_csv('98-401-X2016043_English_CSV_data.csv')
# Out:
# C:\Users\adam1\AppData\Local\Temp\ipykernel_41660\3717547986.py:2: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   t = pd.read_csv('98-401-X2016043_English_CSV_data.csv')

# %%
t['DIM: Profile of Census Tracts (2247)'].value_counts()
# Out:
# DIM: Profile of Census Tracts (2247)
# French                46160
# English               46160
# English and French    40390
# Korean                34620
# Japanese              34620
#                       ...
# 45 to 49 years         5770
# 40 to 44 years         5770
# 35 to 39 years         5770
# 30 to 34 years         5770
# 25 to 29 years         5770
# Name: count, Length: 1134, dtype: int64

# %%
import pandas as pd
test1 = pd.read_csv('final_data_agg.csv')
test2 = pd.read_csv('final_data_long.csv')

# %%
print(len(test1))
print(len(test1.dropna()))
# Out:
# 6507
# 3243

# %%
data1.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data1.info()
#
# NameError: name 'data1' is not defined

# %%
dat = data1.pivot_table(index = ['ALT_GEO_CODE', 'CENSUS_YEAR', 'AGGREGATE_CT'], columns = ['CHARACTERISTIC_NAME'], values = 'C1_COUNT_TOTAL').reset_index()
dat.groupby(['AGGREGATE_CT', 'CENSUS_YEAR']).median().reset_index()
# Out:
# CHARACTERISTIC_NAME  AGGREGATE_CT  CENSUS_YEAR  ALT_GEO_CODE  \
# 0                           10001         2016     10001.000
# 1                           10001         2021     10001.000
# 2                           10002         2016     10002.000
# 3                           10002         2021     10002.000
# 4                           10003         2016     10003.015
# ...                           ...          ...           ...
# 6424                      9700101         2021   9700101.000
# 6425                      9700102         2016   9700102.000
# 6426                      9700102         2021   9700102.000
# 6427                      9700103         2016   9700103.015
# 6428                      9700103         2021   9700103.015
#
# CHARACTERISTIC_NAME  Average age of the population  \
# 0                                            41.40
# 1                                            43.60
# 2                                            46.00
# ...

# %%
print(data2[(data2['Average age of the population, 2016'].isna()) & ~(data2['Average age of the population, 2021'].isna())])
# Out:
# CHARACTERISTIC_NAME  ALT_GEO_CODE  Average age of the population, 2016  \
# 872                    4620268.03                                  NaN
# 1587                   5050050.00                                  NaN
# 1962                   5350006.00                                  NaN
# 2192                   5350205.00                                  NaN
# 4146                   8100010.00                                  NaN
# 4394                   8350001.01                                  NaN
# 4735                   9300012.04                                  NaN
#
# CHARACTERISTIC_NAME  Average size of census families, 2016  \
# 872                                                    NaN
# 1587                                                   NaN
# 1962                                                   NaN
# 2192                                                   NaN
# 4146                                                   NaN
# ...

# %%
proc.data_2016[proc.data_2016['C1_COUNT_TOTAL'] == 'x']
# Out:
#           CENSUS_YEAR  ALT_GEO_CODE  CHARACTERISTIC_ID  \
# 267431           2016    2050130.05                 39
# 267465           2016    2050130.05                 73
# 292148           2016    2050132.09                 39
# 292182           2016    2050132.09                 73
# 321359           2016    2050154.01                 39
# ...               ...           ...                ...
# 12529344         2016    9330290.06                 73
# 12551780         2016    9330400.07                 39
# 12551814         2016    9330400.07                 73
# 12554027         2016    9330400.08                 39
# 12554061         2016    9330400.08                 73
#
#                             CHARACTERISTIC_NAME C1_COUNT_TOTAL
# 267431      Average age of the population, 2016              x
# 267465    Average size of census families, 2016              x
# 292148      Average age of the population, 2016              x
# ...

# %%
proc.data_2016.pivot_table(index = ['ALT_GEO_CODE'], columns = ['CHARACTERISTIC_NAME'], values = 'C1_COUNT_TOTAL').reset_index()
# Out:
# CHARACTERISTIC_NAME  ALT_GEO_CODE  Average age of the population, 2016  \
# 0                            1.00                                 40.3
# 1                          205.00                                 40.9
# 2                          305.00                                 41.7
# 3                          310.00                                 42.3
# 4                          320.00                                 40.7
# ...                           ...                                  ...
# 5760                   9700100.00                                 43.0
# 5761                   9700101.00                                 41.9
# 5762                   9700102.00                                 41.2
# 5763                   9700103.01                                 35.7
# 5764                   9700103.02                                 40.2
#
# CHARACTERISTIC_NAME  Average size of census families, 2016  \
# ...

# %%
print(data1.head(6))
data2.head()
# Out:
#       CENSUS_YEAR  ALT_GEO_CODE  CHARACTERISTIC_ID  \
# 2247         2016       10001.0                  1
# 2250         2016       10001.0                  4
# 2252         2016       10001.0                  6
# 2285         2016       10001.0                 39
# 2319         2016       10001.0                 73
# 4494         2016       10002.0                  1
#
#                                 CHARACTERISTIC_NAME  C1_COUNT_TOTAL
# 2247                               Population, 2016          1734.0
# 2250                  Total private dwellings, 2016           719.0
# 2252  Population density per square kilometre, 2016           171.7
# 2285            Average age of the population, 2016            41.4
# 2319          Average size of census families, 2016             2.8
# 4494                               Population, 2016          4538.0
# CHARACTERISTIC_NAME  ALT_GEO_CODE  Average age of the population, 2016  \
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 57901 entries, 2247 to 16564851
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CENSUS_YEAR          57901 non-null  int64
#  1   ALT_GEO_CODE         57901 non-null  float64
#  2   CHARACTERISTIC_ID    57901 non-null  int64
#  3   CHARACTERISTIC_NAME  57901 non-null  object
#  4   C1_COUNT_TOTAL       57712 non-null  float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 2.7+ MB

# %%
proc.data_2021.pivot_table(index = ['ALT_GEO_CODE'], columns = ['CHARACTERISTIC_NAME'], values = 'C1_COUNT_TOTAL').reset_index().info()#.drop(columns = ['CHARACTERISTIC_NAME'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6240 entries, 0 to 6239
# Data columns (total 6 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   ALT_GEO_CODE                                   6240 non-null   float64
#  1   Average age of the population, 2021            6165 non-null   float64
#  2   Average size of census families, 2021          6161 non-null   float64
#  3   Population density per square kilometre, 2021  6240 non-null   float64
#  4   Population, 2021                               6240 non-null   float64
#  5   Total private dwellings, 2021                  6240 non-null   float64
# dtypes: float64(6)
# memory usage: 292.6 KB

# %%
import seaborn as sns

grouped = data1.groupby('CENSUS_YEAR')['Average size of census families']

# %%
data21 = pd.read_csv('98-401-X2021007_English_CSV_data.csv', encoding = 'latin1')
data16 = pd.read_csv('98-401-X2016043_English_CSV_data.csv')
# Out:
# C:\Users\adam1\AppData\Local\Temp\ipykernel_57508\799057009.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data21 = pd.read_csv('98-401-X2021007_English_CSV_data.csv', encoding = 'latin1')
# C:\Users\adam1\AppData\Local\Temp\ipykernel_57508\799057009.py:2: DtypeWarning: Columns (3,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   data16 = pd.read_csv('98-401-X2016043_English_CSV_data.csv')

# %%
data16.head()
# Out:
#    CENSUS_YEAR  GEO_CODE (POR)  GEO_LEVEL    GEO_NAME  GNR  GNR_LF  \
# 0         2016             1.0          1  St. John's  3.5     5.3
# 1         2016             1.0          1  St. John's  3.5     5.3
# 2         2016             1.0          1  St. John's  3.5     5.3
# 3         2016             1.0          1  St. John's  3.5     5.3
# 4         2016             1.0          1  St. John's  3.5     5.3
#
#    DATA_QUALITY_FLAG  ALT_GEO_CODE  \
# 0                  0             1
# 1                  0             1
# 2                  0             1
# 3                  0             1
# 4                  0             1
#
#             DIM: Profile of Census Tracts (2247)  \
# 0                               Population, 2016
# 1                               Population, 2011
# 2     Population percentage change, 2011 to 2016
# 3                        Total private dwellings
# 4  Private dwellings occupied by usual residents
#
# ...

# %%
import pandas as pd
ada16 = pd.read_csv('98-401-X2016050_English_CSV_data.csv')
ada21 = pd.read_csv('98-401-X2021012CI_English_CSV_data.csv', encoding = 'latin1')
# Out:
# C:\Users\adam1\AppData\Local\Temp\ipykernel_57508\1686457560.py:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   ada16 = pd.read_csv('98-401-X2016050_English_CSV_data.csv')

# %%
print(len(data16['GEO_CODE (POR)'].unique()))
print(len(data21['ALT_GEO_CODE'].unique()))
# Out:
# 5770
# 6297

# %%
data16.head()
data16['GEO_CODE (POR)'].value_counts()
# Out:
# GEO_CODE (POR)
# 1.00          2247
# 10001.00      2247
# 10002.00      2247
# 10003.01      2247
# 10003.02      2247
#               ...
# 9700100.00    2247
# 9700101.00    2247
# 9700102.00    2247
# 9700103.01    2247
# 9700103.02    2247
# Name: count, Length: 5770, dtype: int64

# %%
data16['AGGREGATE_CT'] = data16['GEO_CODE (POR)'].astype(int)
data21['AGGREGATE_CT'] = data21['ALT_GEO_CODE'].astype(int)

# %%
geo21 = data16['AGGREGATE_CT'].unique()
geo16= data21['AGGREGATE_CT'].unique()
matches = []
counter = 0
for item in geo21:
    if item in geo16:
        matches.append(item)
    else:
        print(item)
    counter+=1
print(len(matches))
# Out:
# 8600110
# 8600130
# 9150100
# 9150101
# 3277
